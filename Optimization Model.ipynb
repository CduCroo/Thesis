# %%
# imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
import pulp
import math as m
import seaborn as sns
from collections import defaultdict
from pulp import GUROBI
import random

# %%
## FINAL FEATURE SELECTION

feats = ['HRk', 'HAvAge', 'HW', 'HL', 'HOL', 'HPTS%', 'HSOW', 'HSRS', 'HSOS', 'HGF/G', 
         'HGA/G', 'HPP', 'HPPO', 'HPPA', 'HPPOA', 'HSH', 'HSHA', 'HPIM/G', 'HS%', 'HSV%', 
         'HSO', 'HCAN', 'VRk', 'VAvAge', 'VL', 'VPP', 'VPPO', 'VSH', 'VPIM/G', 'VoPIM/G', 
         'VS%', 'VSV%', 'MDAY', 'TDAY', 'WDAY', 'ThDAY', 'FDAY', 'SDAY', 'SuDAY', 'DIV', 'CAP', 
         'LCAP', 'HSTAR']

# %%
# load data
df_att_all = pd.read_csv('attendance data with features.csv')
df_matchup_data_all = pd.read_csv('2024-25 matchups features.csv')

# only feature selection
df_att = df_att_all[['A', 'PA', 'LA'] + feats]
df_matchup_data = df_matchup_data_all[['H', 'V'] + feats]

# Set random seed
rand_seed = 34

# %%
'''
# train model
# as determined from Data Analysis
# A, XGBoost: n_estimators = 100, min_samples_split = 2, min_samples_leaf = 5, max_depth = 10, subsample = 0.7, learning_rate = 0.05

model = GradientBoostingRegressor(
            n_estimators = 100, min_samples_split = 2, min_samples_leaf = 5, 
            max_depth = 10, subsample = 0.7, learning_rate = 0.05
        )

X = df_att.drop(columns=['A', 'LA', 'PA', 'LCAP'])
y = df_att['A']

# Fit the model (on all data)
model.fit(X, y)
'''
# Out:
# "\n# train model\n# as determined from Data Analysis\n# A, XGBoost: n_estimators = 100, min_samples_split = 2, min_samples_leaf = 5, max_depth = 10, subsample = 0.7, learning_rate = 0.05\n\nmodel = GradientBoostingRegressor(\n            n_estimators = 100, min_samples_split = 2, min_samples_leaf = 5, \n            max_depth = 10, subsample = 0.7, learning_rate = 0.05\n        )\n\nX = df_att.drop(columns=['A', 'LA', 'PA', 'LCAP'])\ny = df_att['A']\n\n# Fit the model (on all data)\nmodel.fit(X, y)\n"

# %%
# train model
# as determined from Data Analysis
# A, Random Forest: n_estimators = 200, min_samples_split = 20, min_samples_leaf = 5

model = RandomForestRegressor(
            n_estimators = 200, min_samples_split = 20, min_samples_leaf = 5
        )

X = df_att.drop(columns=['A', 'LA', 'PA', 'LCAP'])
y = df_att['A']

# Fit the model (on all data)
model.fit(X, y)
# Out:
# RandomForestRegressor(min_samples_leaf=5, min_samples_split=20,
#                       n_estimators=200)

# %%
# ensure columns match the model's expected feature names
expected_features = model.feature_names_in_

# reorder df_matchup_data to have the same feature order as the model
df_matchup_data_ordered = df_matchup_data[expected_features].copy()

# add back the extra columns (Home team, Visiting team, Capacity)
extra_cols = ['H', 'V', 'CAP']
df_matchup_data_ordered[extra_cols] = df_matchup_data[extra_cols]

# %%
# teams dictionairy
teams_dict = {
    'Anaheim Ducks': 0,
    'Boston Bruins': 1,
    'Buffalo Sabres': 2,
    'Calgary Flames': 3,
    'Carolina Hurricanes': 4,
    'Chicago Blackhawks': 5,
    'Colorado Avalanche': 6,
    'Columbus Blue Jackets': 7,
    'Dallas Stars': 8,
    'Detroit Red Wings': 9,
    'Edmonton Oilers': 10,
    'Florida Panthers': 11,
    'Los Angeles Kings': 12,
    'Minnesota Wild': 13,
    'Montreal Canadiens': 14,
    'Nashville Predators': 15,
    'New Jersey Devils': 16,
    'New York Islanders': 17,
    'New York Rangers': 18,
    'Ottawa Senators': 19,
    'Philadelphia Flyers': 20,
    'Pittsburgh Penguins': 21,
    'San Jose Sharks': 22,
    'Seattle Kraken': 23,
    'St. Louis Blues': 24,
    'Tampa Bay Lightning': 25,
    'Toronto Maple Leafs': 26,
    'Utah Hockey Club': 27,  # used to be Arizona Coyotes
    'Vancouver Canucks': 28,
    'Vegas Golden Knights': 29,
    'Washington Capitals': 30,
    'Winnipeg Jets': 31
}

teams_dict_inv = {v: k for k, v in teams_dict.items()}

# Mapping full day names to your dummy variable names
day_mapping = {
    "Monday": "MDAY",
    "Tuesday": "TDAY",
    "Wednesday": "WDAY",
    "Thursday": "ThDAY",
    "Friday": "FDAY",
    "Saturday": "SDAY",
    "Sunday": "SuDAY"
}

# %%
# current schedule (2024-25 season)

games = pd.read_csv('season results/2024-25 season results.csv')

games.head()
# Out:
#          Date      Time             Visitor  G_Visitor               Home  \
# 0  2024-10-04  13:00:00   New Jersey Devils        4.0     Buffalo Sabres
# 1  2024-10-05  10:00:00      Buffalo Sabres        1.0  New Jersey Devils
# 2  2024-10-08  19:00:00       Boston Bruins        4.0   Florida Panthers
# 3  2024-10-08  16:30:00     St. Louis Blues        3.0     Seattle Kraken
# 4  2024-10-08  22:00:00  Chicago Blackhawks        2.0   Utah Hockey Club
#
#    G_Home OT_SO  Attendance   LOG                     Notes       Day
# 0     1.0   NaN     16913.0  2:27  at O2 Arena (Prague, CZ)    Friday
# 1     3.0   NaN     16722.0  2:26  at O2 Arena (Prague, CZ)  Saturday
# 2     6.0   NaN     19813.0  2:39                       NaN   Tuesday
# 3     2.0   NaN     17151.0  2:37                       NaN   Tuesday
# 4     5.0   NaN     11131.0  2:30                       NaN   Tuesday

# %%
# predictors (stats) per team
df_pred = pd.read_csv('data season 2024-25.csv')
df_pred = df_pred.set_index('Team')

df_pred.head()
# Out:
#                       Rk  AvAge  GP   W   L  OL  PTS   PTS%   GF   GA  ...  \
# Team                                                                   ...
# New York Rangers     1.0   29.1  82  55  23   4  114  0.695  278  226  ...
# Dallas Stars         2.0   29.3  82  52  21   9  113  0.689  294  232  ...
# Carolina Hurricanes  3.0   29.4  82  52  23   7  111  0.677  277  211  ...
# Winnipeg Jets        4.0   29.4  82  52  24   6  110  0.671  259  198  ...
# Florida Panthers     5.0   29.5  82  52  24   6  110  0.671  265  198  ...
#
#                      oPIM/G     S    S%    SA    SV%  SO  CAN    CAP  \
# Team
# New York Rangers       10.4  2582  10.8  2418  0.907   6    0  18006
# Dallas Stars            7.5  2588  11.4  2350  0.901   4    0  18408
# Carolina Hurricanes     8.0  2733  10.1  2101  0.900   8    0  18680
# Winnipeg Jets           8.9  2488  10.4  2429  0.918   8    1  15225
# Florida Panthers       13.5  2764   9.6  2279  0.913   8    0  19109
#
# ...

# %%
# game scheduling matrix

# pivot table to count games between teams
matchups = games.pivot_table(
    index = 'Visitor', 
    columns = 'Home', 
    values = 'Date',
    aggfunc = 'count', 
    fill_value = 0)         # a team cannot play itself

# reset column and index names
matchups.index.name = 'Away Team'
matchups.columns.name = 'Home Team'

matchups.head()
# Out:
# Home Team            Anaheim Ducks  Boston Bruins  Buffalo Sabres  \
# Away Team
# Anaheim Ducks                    0              1               1
# Boston Bruins                    1              0               2
# Buffalo Sabres                   1              2               0
# Calgary Flames                   2              1               1
# Carolina Hurricanes              1              1               2
#
# Home Team            Calgary Flames  Carolina Hurricanes  Chicago Blackhawks  \
# Away Team
# Anaheim Ducks                     2                    1                   1
# Boston Bruins                     1                    2                   1
# Buffalo Sabres                    1                    1                   1
# Calgary Flames                    0                    1                   1
# Carolina Hurricanes               1                    0                   1
#
# Home Team            Colorado Avalanche  Columbus Blue Jackets  Dallas Stars  \
# ...

# %%
# H = matrix of home games for teams on certain days
# Hjt = home game for team j on day t
# from current schedule

# we will just number all days that currently have a game 0-N (idk how many days there are yet)
# j = number of team (from team_dict)

# number all unique days with games
unique_days = games['Date'].drop_duplicates().reset_index(drop = True)

# dictionary for game day to number (for ease)
day_to_id = {day: idx for idx, day in enumerate(unique_days)}

# inverse dictionary for later
id_to_day = {v: k for k, v in day_to_id.items()}

# create empty 32 x N matrix
num_teams = len(teams_dict)
num_days = len(unique_days)
H = np.zeros((num_teams, num_days), dtype = int)

# number of weeks
num_weeks = num_days // 7

# populate H matrix
for _, game in games.iterrows():
    home_team_id = teams_dict[game['Home']]
    day_id = day_to_id[game['Date']]
    H[home_team_id, day_id] = 1

# convert to df for better visualization (might not do later)
H_df = pd.DataFrame(H, index = teams_dict.keys(), columns = unique_days)

H_df.head()
# Out:
# Date                 2024-10-04  2024-10-05  2024-10-08  2024-10-09  \
# Anaheim Ducks                 0           0           0           0
# Boston Bruins                 0           0           0           0
# Buffalo Sabres                1           0           0           0
# Calgary Flames                0           0           0           0
# Carolina Hurricanes           0           0           0           0
#
# Date                 2024-10-10  2024-10-11  2024-10-12  2024-10-13  \
# Anaheim Ducks                 0           0           0           0
# Boston Bruins                 1           0           1           0
# Buffalo Sabres                1           0           1           0
# Calgary Flames                0           0           1           0
# Carolina Hurricanes           0           1           0           0
#
# Date                 2024-10-14  2024-10-15  ...  2025-04-08  2025-04-09  \
# ...

# %%
# filter rows where 'Notes' is not empty
special_games = games[games['Notes'].notna() & (games['Notes'] != '')]

# create an empty list to hold special games
special = []

# populate the 'special' list with [visiting_id, home_id, day_id] for each special game
for _, game in special_games.iterrows():
    visiting_id = teams_dict[game['Visitor']]
    home_id = teams_dict[game['Home']]
    day_id = day_to_id[game['Date']]
    
    # Append the special game information
    special.append([visiting_id, home_id, day_id])

# convert 'special' to a numpy array
special = np.array(special)

# %%
# G = number of games team i plays against team j at team j's home
# the matchups dataframe as a matrix

G = matchups.to_numpy()

# %%
# Aijt = attendance for game where team i plays team j at team j's home on day t

# initialize
A = np.zeros((num_teams, num_teams, num_days))

# day id to date dictionary: id_to_day
# gradient boosting model: model
# team id to name dictionary: teams_dict_inv

# for every team
for j in range(num_teams):
    if teams_dict_inv[j] != 'Utah Hockey Club':
        Hjt = H[j]
        # check home games
        for t in range(len(Hjt)):
            if Hjt[t] == 1:
                # days of week of home games
                date_str = id_to_day[t]
                day_of_week = pd.to_datetime(date_str).day_name()
                
                # visiting team
                for i in range(num_teams):
                    if (i != j) and (teams_dict_inv[i] != 'Utah Hockey Club'):
                        # row where home team is j and visiting team is i
                        row_index = df_matchup_data.index[
                            (df_matchup_data_ordered['H'] == teams_dict_inv[j]) & (df_matchup_data_ordered['V'] == teams_dict_inv[i])
                        ]

                        # Reset all dummy variables for days to 0
                        for col in day_mapping.values():
                            df_matchup_data_ordered.loc[row_index, col] = 0
                        
                        # ensure the row exists and the day is in our mapping
                        if not row_index.empty and day_of_week in day_mapping:
                            # Set the corresponding dummy variable to 1
                            df_matchup_data_ordered.loc[row_index, day_mapping[day_of_week]] = 1
                        
                        # Ensure it's a 2D array for sklearn
                        # perc_att = model.predict(df_matchup_data_ordered.loc[row_index].drop(columns=['H', 'V']))[0]
                        att = model.predict(df_matchup_data_ordered.loc[row_index].drop(columns=['H', 'V']))[0]
                        
                        # round? --> cannot have non-integer attendance??
                        # A[i][j][t] = round(perc_att * df_matchup_data_ordered.iloc[row_index[0]]['CAP'])
                        A[i][j][t] = round(att)

# %%
# predictions for leafs (check)
# ends should have same values, middle maybe not
for i in range(num_teams):
    print(f"Team {teams_dict_inv[i]} vs Team {teams_dict_inv[26]}:")
    print(A[i][26][6:14])
# Out:
# Team Anaheim Ducks vs Team Toronto Maple Leafs:
# [18972.     0.     0.     0. 18813.     0.     0. 18972.]
# Team Boston Bruins vs Team Toronto Maple Leafs:
# [19026.     0.     0.     0. 18918.     0.     0. 19026.]
# Team Buffalo Sabres vs Team Toronto Maple Leafs:
# [18959.     0.     0.     0. 18820.     0.     0. 18959.]
# Team Calgary Flames vs Team Toronto Maple Leafs:
# [18986.     0.     0.     0. 18824.     0.     0. 18986.]
# Team Carolina Hurricanes vs Team Toronto Maple Leafs:
# [19024.     0.     0.     0. 18909.     0.     0. 19024.]
# Team Chicago Blackhawks vs Team Toronto Maple Leafs:
# [18960.     0.     0.     0. 18823.     0.     0. 18960.]
# Team Colorado Avalanche vs Team Toronto Maple Leafs:
# [19022.     0.     0.     0. 18909.     0.     0. 19022.]
# Team Columbus Blue Jackets vs Team Toronto Maple Leafs:
# [18948.     0.     0.     0. 18788.     0.     0. 18948.]
# Team Dallas Stars vs Team Toronto Maple Leafs:
# ...

# %%
# Create a dictionary for the current schedule as a warm-start
current_schedule = {}

for _, game in games.iterrows():
    home_team = game['Home']
    away_team = game['Visitor']
    game_date = game['Date']

    # Convert to indices
    day_id = day_to_id[game_date]
    home_team_id = teams_dict[home_team]
    away_team_id = teams_dict[away_team]

    # Store in dictionary
    current_schedule[(away_team_id, home_team_id, day_id)] = 1

# Initialize an empty schedule array
X_schedule_current = np.zeros((num_teams, num_teams, num_days))

# Populate with the current schedule
for _, game in games.iterrows():
    home_team = game['Home']
    away_team = game['Visitor']
    game_date = game['Date']

    # Convert team names and date to indices
    day_id = day_to_id[game_date]
    home_team_id = teams_dict[home_team]
    away_team_id = teams_dict[away_team]

    # Mark the game in the schedule matrix
    X_schedule_current[away_team_id, home_team_id, day_id] = 1

# %%
violations_1day = 0

for i in range(num_teams):
    for t in range(num_days):
        games_played = np.sum(X_schedule_current[i, :, t]) + np.sum(X_schedule_current[:, i, t])  # Sum home & away games
        if games_played > 1:
            violations_1day += 1
            print(f"Constraint violation: Team {i} plays {games_played} games on day {t}.")

print(f"Total violations (1 game per day): {violations_1day}\n")

violations_3days = 0

for i in range(num_teams):
    for t in range(num_days - 2):  # Ensuring t+2 is within range
        games_played = np.sum(X_schedule_current[i, :, t:t+3]) + np.sum(X_schedule_current[:, i, t:t+3])  # Home + Away
        if games_played > 2:
            violations_3days += 1
            print(f"Constraint violation: Team {i} plays more than 2 games in 3-day span ({t}-{t+2}).")

print(f"Total violations (max 2 games in 3 days): {violations_3days}\n")

violations_5days = 0

for i in range(num_teams):
    for t in range(num_days - 4):  # Ensure t+4 is within range
        if np.sum(X_schedule_current[i, :, t:t+5]) + np.sum(X_schedule_current[:, i, t:t+5]) > 3:
            violations_5days += 1
            print(f"Constraint violation: Team {i} plays more than 3 games in 5-day span ({t}-{t+4}).")

print(f"Total violations (max 3 games in 5 days): {violations_5days}\n")

# Find first Sunday (day index)
start_day_index = 2  # The first Sunday is at index 2
first_sunday = (7 - start_day_index) % 7  # Adjusted for Friday start

violations_week = 0

for i in range(num_teams):
    for w in range(num_weeks):
        # Compute the start and end of the current week (Sunday-Saturday)
        start_day = first_sunday + (w * 7)  # First Sunday of week w
        end_day = min(start_day + 7, num_days)  # Saturday of week w

        # Sum the games played by team i and all other teams within that week
        games_played = np.sum(X_schedule_current[i, :, start_day:end_day]) + np.sum(X_schedule_current[:, i, start_day:end_day])
        
        # Check if the team plays fewer than 2 games in that week
        if games_played < 2:
            violations_week += 1
            print(f"Constraint violation: Team {i} plays {games_played} games in week {w} ({start_day}-{end_day-1}).")

print(f"Total violations (min 2 games per Sunday-Saturday week): {violations_week}")
# Out:
# Total violations (1 game per day): 0
#
# Constraint violation: Team 1 plays more than 2 games in 3-day span (51-53).
# Constraint violation: Team 1 plays more than 2 games in 3-day span (77-79).
# Constraint violation: Team 2 plays more than 2 games in 3-day span (52-54).
# Constraint violation: Team 3 plays more than 2 games in 3-day span (52-54).
# Constraint violation: Team 4 plays more than 2 games in 3-day span (52-54).
# Constraint violation: Team 4 plays more than 2 games in 3-day span (76-78).
# Constraint violation: Team 4 plays more than 2 games in 3-day span (77-79).
# Constraint violation: Team 6 plays more than 2 games in 3-day span (52-54).
# Constraint violation: Team 7 plays more than 2 games in 3-day span (77-79).
# Constraint violation: Team 11 plays more than 2 games in 3-day span (52-54).
# Constraint violation: Team 12 plays more than 2 games in 3-day span (52-54).
# Constraint violation: Team 13 plays more than 2 games in 3-day span (52-54).
# ...

# %%
# revisits
team_to_div = {
    'Toronto Maple Leafs': 'atl', 'Florida Panthers': 'atl', 'Tampa Bay Lightning': 'atl',
    'Detroit Red Wings': 'atl', 'Ottawa Senators': 'atl', 'Boston Bruins': 'atl',
    'Montreal Canadiens': 'atl', 'Buffalo Sabres': 'atl',
    
    'Carolina Hurricanes': 'met', 'New Jersey Devils': 'met', 'New York Rangers': 'met',
    'New York Islanders': 'met', 'Pittsburgh Penguins': 'met', 'Washington Capitals': 'met',
    'Philadelphia Flyers': 'met', 'Columbus Blue Jackets': 'met',
    
    'Colorado Avalanche': 'cen', 'Dallas Stars': 'cen', 'Winnipeg Jets': 'cen',
    'Minnesota Wild': 'cen', 'Nashville Predators': 'cen', 'St. Louis Blues': 'cen',
    'Utah Hockey Club': 'cen', 'Chicago Blackhawks': 'cen',
    
    'Vegas Golden Knights': 'pac', 'Edmonton Oilers': 'pac', 'Los Angeles Kings': 'pac',
    'Seattle Kraken': 'pac', 'Calgary Flames': 'pac', 'Vancouver Canucks': 'pac',
    'San Jose Sharks': 'pac', 'Anaheim Ducks': 'pac'
}

# Dictionary to store the last played date for each matchup
last_meeting = defaultdict(lambda: -1000)  # Initialize with a very low day index

# Convert game dates to numeric day indices
games['DayIndex'] = games['Date'].map(day_to_id)  # Convert dates to day indices

# Sort games by date to process them sequentially
games_sorted = games.sort_values(by='DayIndex')

# Track violations
violations = []

# Iterate through sorted games
for _, game in games_sorted.iterrows():
    home_team = game['Home']
    away_team = game['Visitor']
    day_id = game['DayIndex']
    
    matchup = tuple(sorted([home_team, away_team]))  # Ensure (A, B) == (B, A)
    
    # Check previous meeting date
    last_day = last_meeting[matchup]
    
    if last_day != -1000:  # Ensure this is not the first occurrence
        time_gap = day_id - last_day
        
        # Determine if it's an intra-division or inter-division matchup
        if team_to_div[home_team] == team_to_div[away_team]:  # Intra-division
            if time_gap < 14:
                violations.append((home_team, away_team, last_day, day_id, "Intra-division"))
        else:  # Inter-division
            if time_gap < 30:
                violations.append((home_team, away_team, last_day, day_id, "Inter-division"))
    
    # Update last meeting date
    last_meeting[matchup] = day_id

# Print results
if violations:
    print(f"Found {len(violations)} scheduling violations:")
    for v in violations:
        print(f"{v[0]} vs. {v[1]}: {v[4]} violation ({v[3] - v[2]} days apart, required {14 if v[4] == 'Intra-division' else 30})")
else:
    print("No violations found!")
# Out:
# Found 254 scheduling violations:
# New Jersey Devils vs. Buffalo Sabres: Inter-division violation (1 days apart, required 30)
# Boston Bruins vs. Florida Panthers: Intra-division violation (6 days apart, required 14)
# Detroit Red Wings vs. New York Rangers: Inter-division violation (3 days apart, required 30)
# Philadelphia Flyers vs. Vancouver Canucks: Inter-division violation (8 days apart, required 30)
# New Jersey Devils vs. Washington Capitals: Intra-division violation (7 days apart, required 14)
# Columbus Blue Jackets vs. Minnesota Wild: Inter-division violation (9 days apart, required 30)
# Nashville Predators vs. Detroit Red Wings: Inter-division violation (7 days apart, required 30)
# Anaheim Ducks vs. San Jose Sharks: Intra-division violation (10 days apart, required 14)
# Washington Capitals vs. Philadelphia Flyers: Intra-division violation (1 days apart, required 14)
# San Jose Sharks vs. Los Angeles Kings: Intra-division violation (5 days apart, required 14)
# ...

# %%
### NO FAIRNESS CONSTR

# Xijt = team i plays team j at team j's home on day t

# we must have
# Xijt <= Hjt  (maybe don't need this one)
# sum(i) Xijt == Hjt

# sum(t) Xijt == Gij
# sum(j) Xijt == 41 (maybe don't need this one)

# create linear program (using integer programming for the binary decisions)
prob = pulp.LpProblem('scheduling', pulp.LpMaximize)

# decision variables (binary)
X = pulp.LpVariable.dicts('X', (range(num_teams), range(num_teams), range(num_days)), cat = 'Binary')

# objective function
prob += pulp.lpSum(X[i][j][t] * A[i][j][t] for i in range(num_teams) for j in range(num_teams) for t in range(num_days))

# constraints
# sum(i) Xijt == Hjt
for j in range(num_teams):
    for t in range(num_days):
        prob += pulp.lpSum(X[i][j][t] for i in range(num_teams)) == H[j, t]

# sum(t) Xijt == Gij
for i in range(num_teams):
    for j in range(num_teams):
        prob += pulp.lpSum(X[i][j][t] for t in range(num_days)) == G[i, j]

# xijt = 1 for entries [i, j, t] in special
for s in range(len(special)):
    # visiting team, home team, day
    i, j, t = special[s]
    prob += X[i][j][t] == 1

# no more than one game per day
for i in range(num_teams):
    for t in range(num_days):
        prob += pulp.lpSum((X[i][j][t] + X[j][i][t]) for j in range(num_teams)) <= 1

# Solve
prob.solve(pulp.PULP_CBC_CMD(msg=True))

objective_value_no_fair = prob.objective.value()

# save X
X_no_fair = [[[int(pulp.value(X[i][j][t])) for t in range(num_days)] for j in range(num_teams)] for i in range(num_teams)]

# Print the objective value
print(f'objective function value: {objective_value_no_fair}')
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/z6/55zl8z_1365b2p_8lkhq6tzr0000gn/T/a71c2d5ef7574aacbe6bc482f586e296-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/z6/55zl8z_1365b2p_8lkhq6tzr0000gn/T/a71c2d5ef7574aacbe6bc482f586e296-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 12427 COLUMNS
# At line 1138500 RHS
# At line 1150923 BOUNDS
# At line 1333196 ENDATA
# Problem MODEL has 12422 rows, 182272 columns and 723398 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 2.1557e+07 - 38.76 seconds
# Cgl0002I 141600 variables fixed
# Cgl0003I 4413 fixed, 0 tightened bounds, 210 strengthened rows, 0 substitutions
# Cgl0003I 6276 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# ...

# %%
X_array = np.array(X_no_fair)

# --- Max 1 game per day ---
violations_1day = 0
for i in range(num_teams):
    for t in range(num_days):
        games_played = np.sum(X_array[i, :, t]) + np.sum(X_array[:, i, t])
        if games_played > 1:
            violations_1day += 1
            # print(f"1-day violation: Team {i} plays {games_played} games on day {t}")
print(f"Total violations (max 1 game per day): {violations_1day}\n")

# --- Max 2 games in 3 days ---
violations_3days = 0
for i in range(num_teams):
    for t in range(num_days - 2):
        games_played = np.sum(X_array[i, :, t:t+3]) + np.sum(X_array[:, i, t:t+3])
        if games_played > 2:
            violations_3days += 1
            # print(f"3-day violation: Team {i} plays {games_played} games from day {t} to {t+2}")
print(f"Total violations (max 2 games in 3 days): {violations_3days}\n")

# --- Max 3 games in 5 days ---
violations_5days = 0
for i in range(num_teams):
    for t in range(num_days - 4):
        games_played = np.sum(X_array[i, :, t:t+5]) + np.sum(X_array[:, i, t:t+5])
        if games_played > 3:
            violations_5days += 1
            # print(f"5-day violation: Team {i} plays {games_played} games from day {t} to {t+4}")
print(f"Total violations (max 3 games in 5 days): {violations_5days}\n")

# --- Min 2 games per week (Sunday-Saturday) ---
violations_week = 0
start_day_index = 2  # Friday = day 0, Sunday = 2
first_sunday = (7 - start_day_index) % 7

for i in range(num_teams):
    for w in range(num_weeks):
        start_day = first_sunday + w * 7
        end_day = min(start_day + 7, num_days)
        games_played = np.sum(X_array[i, :, start_day:end_day]) + np.sum(X_array[:, i, start_day:end_day])
        if games_played < 2:
            violations_week += 1
            # print(f"Week violation: Team {i} plays {games_played} games in week {w} (days {start_day}-{end_day - 1})")
print(f"Total violations (min 2 games per week): {violations_week}")
# Out:
# Total violations (max 1 game per day): 0
#
# 3-day violation: Team 0 plays 3 games from day 5 to 7
# 3-day violation: Team 0 plays 3 games from day 33 to 35
# 3-day violation: Team 0 plays 3 games from day 46 to 48
# 3-day violation: Team 0 plays 3 games from day 72 to 74
# 3-day violation: Team 0 plays 3 games from day 103 to 105
# 3-day violation: Team 0 plays 3 games from day 104 to 106
# 3-day violation: Team 0 plays 3 games from day 105 to 107
# 3-day violation: Team 0 plays 3 games from day 154 to 156
# 3-day violation: Team 0 plays 3 games from day 155 to 157
# 3-day violation: Team 0 plays 3 games from day 156 to 158
# 3-day violation: Team 0 plays 3 games from day 157 to 159
# 3-day violation: Team 0 plays 3 games from day 165 to 167
# 3-day violation: Team 0 plays 3 games from day 166 to 168
# 3-day violation: Team 0 plays 3 games from day 167 to 169
# 3-day violation: Team 0 plays 3 games from day 173 to 175
# 3-day violation: Team 1 plays 3 games from day 6 to 8
# ...

# %%
### NO SLACK VARIABLES

# Xijt = team i plays team j at team j's home on day t

# we must have
# Xijt <= Hjt  (maybe don't need this one)
# sum(i) Xijt == Hjt

# sum(t) Xijt == Gij
# sum(j) Xijt == 41 (maybe don't need this one)

# create linear program (using integer programming for the binary decisions)
prob = pulp.LpProblem('scheduling', pulp.LpMaximize)

# decision variables (binary)
X = pulp.LpVariable.dicts('X', (range(num_teams), range(num_teams), range(num_days)), cat = 'Binary')

# objective function
prob += pulp.lpSum(X[i][j][t] * A[i][j][t] for i in range(num_teams) for j in range(num_teams) for t in range(num_days))

# constraints
# sum(i) Xijt == Hjt
for j in range(num_teams):
    for t in range(num_days):
        prob += pulp.lpSum(X[i][j][t] for i in range(num_teams)) == H[j, t]

# sum(t) Xijt == Gij
for i in range(num_teams):
    for j in range(num_teams):
        prob += pulp.lpSum(X[i][j][t] for t in range(num_days)) == G[i, j]

# xijt = 1 for entries [i, j, t] in special
for s in range(len(special)):
    # visiting team, home team, day
    i, j, t = special[s]
    prob += X[i][j][t] == 1

# fairness constraints
# no more than one game per day
for i in range(num_teams):
    for t in range(num_days):
        prob += pulp.lpSum((X[i][j][t] + X[j][i][t]) for j in range(num_teams)) <= 1

# no more than 2 games in three days
for i in range(num_teams):
    for t in range(num_days - 2):  # Ensure t+2 is within range
        prob += pulp.lpSum((X[i][j][t_p] + X[j][i][t_p]) for j in range(num_teams) for t_p in range(t, t + 3)) <= 2

# no more than 3 games in five days
for i in range(num_teams):
    for t in range(num_days - 4):  # Ensure t+4 is within range
        prob += pulp.lpSum((X[i][j][t_p] + X[j][i][t_p]) for j in range(num_teams) for t_p in range(t, t + 5)) <= 3

# at least 2 games per week
start_day_index = 2  # The first Sunday is at index 2 (Friday start)
first_sunday = (7 - start_day_index) % 7  # Adjusted for Friday start

# Add the constraint to the LP model
for i in range(num_teams):
    for w in range(num_weeks):
        # Compute the start and end of the current week (Sunday-Saturday)
        start_day = first_sunday + (w * 7)  # First Sunday of week w
        end_day = min(start_day + 7, num_days)  # Saturday of week w
        
        # Sum the games played by team i in that week (both as home and away)
        prob += (
            pulp.lpSum(X[i][j][t] for j in range(num_teams) for t in range(start_day, end_day))
            + pulp.lpSum(X[j][i][t] for j in range(num_teams) for t in range(start_day, end_day))
            >= 2
        )

# Warm-start the solver with the current schedule
for (i, j, t), value in current_schedule.items():
    X[i][j][t].setInitialValue(value)  # Set initial value

# Solve
prob.solve(pulp.PULP_CBC_CMD(msg=True))
#prob.solve(GUROBI(msg=True))

objective_value_no_slack = prob.objective.value()

# save X
X_no_slack = [[[int(pulp.value(X[i][j][t])) for t in range(num_days)] for j in range(num_teams)] for i in range(num_teams)]

# Print the objective value
print(f'objective function value: {objective_value_no_slack}')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[58], line 77
#      74     X[i][j][t].setInitialValue(value)  # Set initial value
#      76 # Solve
# ---> 77 prob.solve(pulp.PULP_CBC_CMD(msg=True))
#      78 #prob.solve(GUROBI(msg=True))
#      80 objective_value_no_slack = prob.objective.value()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pulp/pulp.py:1867, in LpProblem.solve(self, solver, **kwargs)
#    1865 # time it
#    1866 self.startClock()
# -> 1867 status = solver.actualSolve(self, **kwargs)
#    1868 self.stopClock()
#    1869 self.restoreObjective(wasNone, dummyVar)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/coin_api.py:112, in COIN_CMD.actualSolve(self, lp, **kwargs)
#     110 def actualSolve(self, lp, **kwargs):
#     111     """Solve a well formulated lp problem"""
# --> 112     return self.solve_CBC(lp, **kwargs)
#
# ...

# %%
X_array = np.array(X_no_slack)

# --- Max 1 game per day ---
violations_1day = 0
for i in range(num_teams):
    for t in range(num_days):
        games_played = np.sum(X_array[i, :, t]) + np.sum(X_array[:, i, t])
        if games_played > 1:
            violations_1day += 1
            # print(f"1-day violation: Team {i} plays {games_played} games on day {t}")
print(f"Total violations (max 1 game per day): {violations_1day}\n")

# --- Max 2 games in 3 days ---
violations_3days = 0
for i in range(num_teams):
    for t in range(num_days - 2):
        games_played = np.sum(X_array[i, :, t:t+3]) + np.sum(X_array[:, i, t:t+3])
        if games_played > 2:
            violations_3days += 1
            # print(f"3-day violation: Team {i} plays {games_played} games from day {t} to {t+2}")
print(f"Total violations (max 2 games in 3 days): {violations_3days}\n")

# --- Max 3 games in 5 days ---
violations_5days = 0
for i in range(num_teams):
    for t in range(num_days - 4):
        games_played = np.sum(X_array[i, :, t:t+5]) + np.sum(X_array[:, i, t:t+5])
        if games_played > 3:
            violations_5days += 1
            # print(f"5-day violation: Team {i} plays {games_played} games from day {t} to {t+4}")
print(f"Total violations (max 3 games in 5 days): {violations_5days}\n")

# --- Min 2 games per week (Sunday-Saturday) ---
violations_week = 0
start_day_index = 2  # Friday = day 0, Sunday = 2
first_sunday = (7 - start_day_index) % 7

for i in range(num_teams):
    for w in range(num_weeks):
        start_day = first_sunday + w * 7
        end_day = min(start_day + 7, num_days)
        games_played = np.sum(X_array[i, :, start_day:end_day]) + np.sum(X_array[:, i, start_day:end_day])
        if games_played < 2:
            violations_week += 1
            # print(f"Week violation: Team {i} plays {games_played} games in week {w} (days {start_day}-{end_day - 1})")
print(f"Total violations (min 2 games per week): {violations_week}")

# %%
### big M
# Create the linear program
prob = pulp.LpProblem('scheduling', pulp.LpMaximize)

# Decision variables (binary)
X = pulp.LpVariable.dicts('X', (range(num_teams), range(num_teams), range(num_days)), cat='Binary')

# Slack variables (continuous, non-negative)
S1 = pulp.LpVariable.dicts('S1', (range(num_teams), range(num_days - 2)), lowBound=0, cat='Continuous')
S2 = pulp.LpVariable.dicts('S2', (range(num_teams), range(num_days - 4)), lowBound=0, cat='Continuous')
S3 = pulp.LpVariable.dicts('S3', (range(num_teams), range(num_weeks)), lowBound=0, cat='Continuous')

# Objective function (maximize attendance while penalizing constraint violations)
M1 = 1000
M2 = 1000
M3 = 1000
prob += (
    pulp.lpSum(X[i][j][t] * A[i][j][t] for i in range(num_teams) for j in range(num_teams) for t in range(num_days))
        - M1 * pulp.lpSum(S1[i][t] for i in range(num_teams) for t in range(num_days - 2))
        - M2 * pulp.lpSum(S2[i][t] for i in range(num_teams) for t in range(num_days - 4))
        - M3 * pulp.lpSum(S3[i][w] for i in range(num_teams) for w in range(num_weeks))
)

# Constraints

# sum(i) Xijt == Hjt
for j in range(num_teams):
    for t in range(num_days):
        prob += pulp.lpSum(X[i][j][t] for i in range(num_teams)) == H[j, t]

# sum(t) Xijt == Gij
for i in range(num_teams):
    for j in range(num_teams):
        prob += pulp.lpSum(X[i][j][t] for t in range(num_days)) == G[i, j]

# xijt = 1 for entries [i, j, t] in special
for s in range(len(special)):
    i, j, t = special[s]
    prob += X[i][j][t] == 1

# Fairness constraints with slack variables
# no more than one game per day
for i in range(num_teams):
    for t in range(num_days):
        prob += pulp.lpSum((X[i][j][t] + X[j][i][t]) for j in range(num_teams)) <= 1

# No more than 2 games in three days
for i in range(num_teams):
    for t in range(num_days - 2):
        prob += (
            pulp.lpSum((X[i][j][t_p] + X[j][i][t_p]) for j in range(num_teams) for t_p in range(t, t + 3)) 
            <= 2 + S1[i][t]
        )

# No more than 3 games in five days
for i in range(num_teams):
    for t in range(num_days - 4):
        prob += (
            pulp.lpSum((X[i][j][t_p] + X[j][i][t_p]) for j in range(num_teams) for t_p in range(t, t + 5)) 
            <= 3 + S2[i][t]
        )

# At least 2 games per week
for i in range(num_teams):
    for w in range(num_weeks):  
        prob += (
            pulp.lpSum((X[i][j][t] + X[j][i][t]) for j in range(num_teams) for t in range(w * 7, min((w + 1) * 7, num_days)))
            >= 2 - S3[i][w]
        )

# Warm-start the solver with the current schedule
for (i, j, t), value in current_schedule.items():
    X[i][j][t].setInitialValue(value)  # Set initial value

# Solve with warm start
prob.solve()

# Get the objective value
objective_value = prob.objective.value()

X_big_M = [[[int(pulp.value(X[i][j][t])) for t in range(num_days)] for j in range(num_teams)] for i in range(num_teams)]

# Print the result
print(f'Objective function value: {objective_value}')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[61], line 76
#      73     X[i][j][t].setInitialValue(value)  # Set initial value
#      75 # Solve with warm start
# ---> 76 prob.solve()
#      78 # Get the objective value
#      79 objective_value = prob.objective.value()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pulp/pulp.py:1867, in LpProblem.solve(self, solver, **kwargs)
#    1865 # time it
#    1866 self.startClock()
# -> 1867 status = solver.actualSolve(self, **kwargs)
#    1868 self.stopClock()
#    1869 self.restoreObjective(wasNone, dummyVar)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/coin_api.py:112, in COIN_CMD.actualSolve(self, lp, **kwargs)
#     110 def actualSolve(self, lp, **kwargs):
#     111     """Solve a well formulated lp problem"""
# --> 112     return self.solve_CBC(lp, **kwargs)
#
# ...

# %%
# Violations of 2 games in 3 days
for i in range(num_teams):
    for t in range(num_days - 2):
        if pulp.value(S1[i][t]) > 0:
            print(f"Team {i} violates 2-in-3-days at day {t}: slack = {pulp.value(S1[i][t])}")

# Violations of 3 games in 5 days
for i in range(num_teams):
    for t in range(num_days - 4):
        if pulp.value(S2[i][t]) > 0:
            print(f"Team {i} violates 3-in-5-days at day {t}: slack = {pulp.value(S2[i][t])}")

# Violations of at least 2 games per week
for i in range(num_teams):
    for w in range(num_weeks):
        if pulp.value(S3[i][w]) > 0:
            print(f"Team {i} plays fewer than 2 games in week {w}: slack = {pulp.value(S3[i][w])}")
# Out:
# Team 0 plays fewer than 2 games in week 0: slack = 1.0
# Team 0 plays fewer than 2 games in week 1: slack = 1.0
# Team 0 plays fewer than 2 games in week 2: slack = 1.0
# Team 0 plays fewer than 2 games in week 10: slack = 1.0
# Team 0 plays fewer than 2 games in week 13: slack = 1.0
# Team 0 plays fewer than 2 games in week 15: slack = 1.0
# Team 0 plays fewer than 2 games in week 17: slack = 1.0
# Team 0 plays fewer than 2 games in week 19: slack = 1.0
# Team 0 plays fewer than 2 games in week 21: slack = 1.0
# Team 0 plays fewer than 2 games in week 22: slack = 1.0
# Team 1 plays fewer than 2 games in week 0: slack = 1.0
# Team 1 plays fewer than 2 games in week 6: slack = 1.0
# Team 1 plays fewer than 2 games in week 8: slack = 1.0
# Team 1 plays fewer than 2 games in week 9: slack = 2.0
# Team 1 plays fewer than 2 games in week 10: slack = 2.0
# Team 1 plays fewer than 2 games in week 12: slack = 1.0
# Team 1 plays fewer than 2 games in week 17: slack = 1.0
# ...

# %%
X_big_M = [[[int(pulp.value(X[i][j][t])) for t in range(num_days)] for j in range(num_teams)] for i in range(num_teams)]

X_array = np.array(X_big_M)

# --- Max 2 games in 3 days ---
violations_3days = 0
for i in range(num_teams):
    for t in range(num_days - 2):
        games_played = np.sum(X_array[i, :, t:t+3]) + np.sum(X_array[:, i, t:t+3])
        if games_played > 2:
            violations_3days += 1
            # print(f"3-day violation: Team {i} plays {games_played} games from day {t} to {t+2}")
print(f"Total violations (max 2 games in 3 days): {violations_3days}\n")

# --- Max 3 games in 5 days ---
violations_5days = 0
for i in range(num_teams):
    for t in range(num_days - 4):
        games_played = np.sum(X_array[i, :, t:t+5]) + np.sum(X_array[:, i, t:t+5])
        if games_played > 3:
            violations_5days += 1
            # print(f"5-day violation: Team {i} plays {games_played} games from day {t} to {t+4}")
print(f"Total violations (max 3 games in 5 days): {violations_5days}\n")

# --- Min 2 games per week (Sunday-Saturday) ---
violations_week = 0
start_day_index = 2  # Friday = day 0, Sunday = 2
first_sunday = (7 - start_day_index) % 7

for i in range(num_teams):
    for w in range(num_weeks):
        start_day = first_sunday + w * 7
        end_day = min(start_day + 7, num_days)
        games_played = np.sum(X_array[i, :, start_day:end_day]) + np.sum(X_array[:, i, start_day:end_day])
        if games_played < 2:
            violations_week += 1
            # print(f"Week violation: Team {i} plays {games_played} games in week {w} (days {start_day}-{end_day - 1})")
print(f"Total violations (min 2 games per week): {violations_week}")
# Out:
# (32, 32, 178)
# 3-day violation: Team 0 plays 3 games from day 32 to 34
# 3-day violation: Team 0 plays 3 games from day 33 to 35
# 3-day violation: Team 0 plays 3 games from day 40 to 42
# 3-day violation: Team 0 plays 3 games from day 51 to 53
# 3-day violation: Team 0 plays 3 games from day 52 to 54
# 3-day violation: Team 0 plays 3 games from day 53 to 55
# 3-day violation: Team 0 plays 3 games from day 58 to 60
# 3-day violation: Team 0 plays 3 games from day 60 to 62
# 3-day violation: Team 0 plays 3 games from day 72 to 74
# 3-day violation: Team 0 plays 3 games from day 82 to 84
# 3-day violation: Team 0 plays 3 games from day 126 to 128
# 3-day violation: Team 0 plays 3 games from day 127 to 129
# 3-day violation: Team 0 plays 3 games from day 128 to 130
# 3-day violation: Team 0 plays 3 games from day 136 to 138
# 3-day violation: Team 0 plays 3 games from day 155 to 157
# 3-day violation: Team 0 plays 3 games from day 161 to 163
# ...

# %%
# put results in df
data_no_slack = []
# data_slack = []

optimized_attendance_no_slack = 0

# loop through all decision variables
for i in range(num_teams):
    for j in range(num_teams):
        for t in range(num_days):
            data_no_slack.append({
                'Visitor': teams_dict_inv[i],
                'Home': teams_dict_inv[j],
                'Date': id_to_day[t],
                'Game Scheduled': X_no_slack[i][j][t]
            })
            optimized_attendance_no_slack += A[i][j][t] * X_no_slack[i][j][t]

            # data_slack.append({
            #     'Visitor': teams_dict_inv[i],
            #     'Home': teams_dict_inv[j],
            #     'Date': id_to_day[t],
            #     'Game Scheduled': X_no_slack[i][j][t]
            # })
            # optimized_attendance_slack += A[i][j][t] * X_slack_warm[i][j][t]

# df with results
df_results_no_slack = pd.DataFrame(data_no_slack)
# df_results_slack = pd.DataFrame(data_slack)

# show only scheduled games
df_results_scheduled_no_slack = df_results_no_slack[df_results_no_slack['Game Scheduled'] == 1]
df_results_scheduled_no_slack = df_results_scheduled_no_slack.sort_values(by = 'Date').reset_index()

# df_results_scheduled_slack = df_results_slack[df_results_slack['Game Scheduled'] == 1]
# df_results_scheduled_slack = df_results_scheduled_slack.sort_values(by = 'Date').reset_index()

display(df_results_scheduled_no_slack.head(10))
# display(df_results_scheduled_slack.head(10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 18
#      10             data_no_slack.append({
#      11                 'Visitor': teams_dict_inv[i],
#      12                 'Home': teams_dict_inv[j],
#      13                 'Date': id_to_day[t],
#      14                 'Game Scheduled': X_no_slack[i][j][t]
#      15             })
#      16             optimized_attendance_no_slack += A[i][j][t] * X_no_slack[i][j][t]
# ---> 18             data_slack.append({
#      19                 'Visitor': teams_dict_inv[i],
#      20                 'Home': teams_dict_inv[j],
#      21                 'Date': id_to_day[t],
#      22                 'Game Scheduled': X_no_slack[i][j][t]
#      23             })
#      24             optimized_attendance_slack += A[i][j][t] * X_slack_warm[i][j][t]
#      26 # df with results
#
# ...

# %%
# find value of current system according to objective function used in optimization (using games)

# current schedule value
current_val = 0

for _, game in games.iterrows():
    # Home and away teams and game date
    home_team = game['Home']
    away_team = game['Visitor']
    game_date = game['Date']
    
    # Day index
    day_id = day_to_id[game_date]
    
    # Team indices
    home_team_id = teams_dict[home_team]
    away_team_id = teams_dict[away_team]
    
    # Add corresponding attendance value
    current_val += A[away_team_id, home_team_id, day_id]

# Print result
print(f'Current schedule attendance value: {current_val}')
print(f'Difference in attendance value - no slack: {optimized_attendance_no_slack - current_val}')
# print(f'Difference in attendance value - slack: {optimized_attendance_slack - current_val}')

print(f'Percentage increase - no slack: {round((optimized_attendance_no_slack - current_val) / current_val * 100, 4)}%')
# print(f'Percentage increase - slack: {round((optimized_attendance_slack - current_val) / current_val * 100, 4)}%')

# %%
# Create a marker for comparing home and away teams
def compare_teams(game, df_results_scheduled, day_to_id, teams_dict):
    # Home and away teams from the current schedule
    home_team = game['Home']
    away_team = game['Visitor']
    game_date = game['Date']
    
    # Day index
    day_id = day_to_id[game_date]
    
    # Team indices for the scheduled game
    home_team_id = teams_dict[home_team]
    away_team_id = teams_dict[away_team]
    
    # Compare if the home and away teams are different in the current schedule vs scheduled
    scheduled_game = df_results_scheduled[
        (df_results_scheduled['Home Team'] == home_team) & 
        (df_results_scheduled['Away Team'] == away_team) & 
        (df_results_scheduled['Day'] == game_date)
    ]
    
    if not scheduled_game.empty:
        return "Same"
    else:
        return "Different"
    
# Apply the comparison function to each game in the schedule
#df_results_scheduled['Comparison'] = df_results_scheduled.apply(
#    lambda row: compare_teams(row, df_results_scheduled, day_to_id, teams_dict), axis=1
#)

# Display the results
#df_results_scheduled.head(10)

#compare_teams(games, df_results_scheduled, day_to_id, teams_dict)
games.head()

# %%
# Merge the dataframes on the relevant columns: 'Day', 'Visitor'/'Away Team', and 'Home'/'Home Team'
merged_df = pd.merge(games[['Date', 'Visitor', 'Home']], 
                     df_results_scheduled[['Date', 'Visitor', 'Home']],
                     left_on=['Date', 'Visitor', 'Home'], 
                     right_on=['Date', 'Visitor', 'Home'], 
                     how='outer', indicator=True)

# Filter rows where there are discrepancies (either from the left or right dataframe)
diff_games = merged_df[merged_df['_merge'] != 'both']

# Print the rows that are different
print(diff_games)

# %%
# same games
same_games = merged_df[merged_df['_merge'] == 'both']

same_games

# %%
# Merge the optimized and current schedule, keeping both visitor teams
merged_attendance = pd.merge(
    games[['Date', 'Home', 'Visitor']].rename(columns={'Visitor': 'Current Visitor'}), 
    df_results_scheduled[['Date', 'Home', 'Visitor']].rename(columns={'Visitor': 'Optimized Visitor'}), 
    on=['Date', 'Home'], 
    how='outer', 
    indicator=True
)

# Add attendance values for both schedules
merged_attendance['Current Attendance'] = merged_attendance.apply(
    lambda row: A[teams_dict[row['Current Visitor']], teams_dict[row['Home']], day_to_id[row['Date']]]
    if pd.notna(row['Current Visitor']) else None, axis=1
)

merged_attendance['Optimized Attendance'] = merged_attendance.apply(
    lambda row: A[teams_dict[row['Optimized Visitor']], teams_dict[row['Home']], day_to_id[row['Date']]]
    if pd.notna(row['Optimized Visitor']) else None, axis=1
)

# Compute the difference
merged_attendance['Attendance Difference'] = (
    merged_attendance['Optimized Attendance'].fillna(0) - merged_attendance['Current Attendance'].fillna(0)
)

# Show results
merged_attendance[['Date', 'Home', 'Current Visitor', 'Optimized Visitor', 
                         'Current Attendance', 'Optimized Attendance', 'Attendance Difference']]

# %%
# Define the Utah Hockey Club name (adjust if needed)
utah_team_name = "Utah Hockey Club"

# Filter out games where Utah Hockey Club is involved
filtered_attendance = merged_attendance[
    (merged_attendance['Home'] != utah_team_name) & 
    (merged_attendance['Current Visitor'] != utah_team_name) & 
    (merged_attendance['Optimized Visitor'] != utah_team_name)
]

# Show only the relevant columns
filtered_attendance[['Date', 'Home', 'Current Visitor', 'Optimized Visitor', 
                           'Current Attendance', 'Optimized Attendance', 'Attendance Difference']]

# %%
# Set up figure
plt.figure(figsize=(15, 6))

# Create bar chart with heatmap-style coloring
barplot = sns.barplot(
    x='Date', y='Attendance Difference', data=filtered_attendance,
    hue='Attendance Difference', palette='coolwarm', dodge=False
)

# Manually set x-axis tick positions to show every 7th date
date_labels = filtered_attendance['Date'].unique()  # Unique dates in order
tick_positions = range(0, len(date_labels), 7)  # Every 7th date

plt.xticks(ticks=tick_positions, labels=[date_labels[i] for i in tick_positions], 
           rotation=90, ha='right', size=8)

# Labels and title
plt.xlabel("Game Date")
plt.ylabel("Attendance Difference")
plt.title("Optimized vs Current Attendance Difference (Excluding Utah Hockey Club)")

# Remove legend (optional)
plt.legend([],[], frameon=False)

# Save the figure
plt.tight_layout()  # Avoid clipping of labels
plt.savefig("attendance_difference_barplot.png", dpi=300, bbox_inches='tight')

plt.close()

# %%
# Get the top 10 rows with the highest attendance differences
top_10_diff_games = filtered_attendance.sort_values(by='Attendance Difference', ascending=False).head(10)

# Print the top 10 games
top_10_diff_games[['Date', 'Home', 'Current Visitor', 'Optimized Visitor', 
                         'Current Attendance', 'Optimized Attendance', 'Attendance Difference']]

# %%
# Get the top 10 rows with the highest attendance differences
top_10_diff_games = filtered_attendance.sort_values(by='Attendance Difference', ascending=True).head(10)

# Print the top 10 games
top_10_diff_games[['Date', 'Home', 'Current Visitor', 'Optimized Visitor', 
                         'Current Attendance', 'Optimized Attendance', 'Attendance Difference']]

# %%
filtered_attendance['Attendance Difference'].describe()

# %%
sns.histplot(filtered_attendance['Attendance Difference'], bins = 30, kde = True, color = 'red')
plt.title('Histogram of Attendance Difference')
plt.xlabel('Attendance Difference')
plt.ylabel('Frequency')
plt.show()

# %%
# Function to compute evaluation metrics with dependent variable transformation
def compute_stats(dep, y, y_pred):
    if dep == 'A':
        y_true_transform, y_pred_transform = y, y_pred

    elif dep == 'LA':
        y_true_transform, y_pred_transform = np.exp(y), np.exp(y_pred)

    elif dep == 'PA':
        y_true_transform, y_pred_transform = y * X['CAP'] , y_pred * X['CAP']

    return {
        "RMSE": m.sqrt(mean_squared_error(y_true_transform, y_pred_transform)),
        "MAE": mean_absolute_error(y_true_transform, y_pred_transform),
        "R²": r2_score(y_true_transform, y_pred_transform)
    }

# %%
# compare predicted to actual attendance
df_att_25 = pd.read_csv('attendance data season 2024-25.csv')

df_att_25_feats = df_att_25[['A'] + feats]

X_25 = df_att_25_feats.drop(columns = ['A', 'LCAP'])
y_25 = df_att_25_feats['A']

y_pred_25 = model.predict(X_25)

# Plot predicted vs actual for the 2024–25 season
fig, ax = plt.subplots(figsize=(6, 6))
ax.scatter(y_25, y_pred_25, alpha=0.5, color='red', marker='.')
ax.plot([min(y_25), max(y_25)], [min(y_25), max(y_25)], color='black', linestyle='--')
ax.set_title("Predicted vs Actual Attendance (2024–25 Season)")
ax.set_xlabel("Actual Attendance")
ax.set_ylabel("Predicted Attendance")
plt.tight_layout()
plt.show()

stats = compute_stats('A', y_25, y_pred_25)
stats

# %%
# Calculate residuals
residuals = y_pred_25 - y_25

# Count over- and underpredictions
over_preds = (residuals > 0).sum()
under_preds = (residuals < 0).sum()
exact_preds = (residuals == 0).sum()

print(f"Overpredictions: {over_preds}")
print(f"Underpredictions: {under_preds}")
print(f"Exact matches: {exact_preds}")

# Histogram of residuals
plt.figure(figsize=(8, 4))
plt.hist(residuals, bins=30, color='purple', alpha=0.7)
plt.axvline(0, color='black', linestyle='--')
plt.title("Distribution of Prediction Errors (Predicted - Actual)")
plt.xlabel("Prediction Error")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %%
# Parameters
num_teams = 32
num_days = 14
num_weeks = num_days // 7  # ceil division for full weeks

# Dummy attendance data
A = [[[random.randint(1000, 5000) if i != j else 0 for t in range(num_days)]
      for j in range(num_teams)] for i in range(num_teams)]

# Arena availability (just all 1s for simplicity)
H = {(j, t): 1 for j in range(num_teams) for t in range(num_days)}

# Each team plays each other once (except self)
G = {(i, j): 1 if i != j else 0 for i in range(num_teams) for j in range(num_teams)}

# One special game: team 0 plays at team 1 on day 2
special = [(0, 1, 2)]

# Problem
prob = pulp.LpProblem("MiniScheduling", pulp.LpMaximize)

# Decision vars
X = pulp.LpVariable.dicts("X", (range(num_teams), range(num_teams), range(num_days)), cat="Binary")

# Slack vars
S1 = pulp.LpVariable.dicts("S1", (range(num_teams), range(num_days - 2)), lowBound=0, cat="Continuous")
S2 = pulp.LpVariable.dicts("S2", (range(num_teams), range(num_days - 4)), lowBound=0, cat="Continuous")
S3 = pulp.LpVariable.dicts("S3", (range(num_teams), range(num_weeks)), lowBound=0, cat="Continuous")

# Objective: attendance minus penalty on constraint violations
M1, M2, M3 = 1000, 1000, 1000
prob += (
    pulp.lpSum(X[i][j][t] * A[i][j][t] for i in range(num_teams) for j in range(num_teams) for t in range(num_days))
    - M1 * pulp.lpSum(S1[i][t] for i in range(num_teams) for t in range(num_days - 2))
    - M2 * pulp.lpSum(S2[i][t] for i in range(num_teams) for t in range(num_days - 4))
    - M3 * pulp.lpSum(S3[i][w] for i in range(num_teams) for w in range(num_weeks))
)

# Constraints

# Home game availability
for j in range(num_teams):
    for t in range(num_days):
        prob += pulp.lpSum(X[i][j][t] for i in range(num_teams)) <= H[j, t]

# Required matchups
for i in range(num_teams):
    for j in range(num_teams):
        prob += pulp.lpSum(X[i][j][t] for t in range(num_days)) <= G[i, j]

# Special fixed games
for i, j, t in special:
    prob += X[i][j][t] == 1

# Max 1 game per day
for i in range(num_teams):
    for t in range(num_days):
        prob += pulp.lpSum(X[i][j][t] + X[j][i][t] for j in range(num_teams)) <= 1

# Max 2 games in 3 days
for i in range(num_teams):
    for t in range(num_days - 2):
        prob += pulp.lpSum(X[i][j][tp] + X[j][i][tp] for j in range(num_teams) for tp in range(t, t+3)) <= 2 + S1[i][t]

# Max 3 games in 5 days
for i in range(num_teams):
    for t in range(num_days - 4):
        prob += pulp.lpSum(X[i][j][tp] + X[j][i][tp] for j in range(num_teams) for tp in range(t, t+5)) <= 3 + S2[i][t]

# Min 2 games per week
for i in range(num_teams):
    for w in range(num_weeks):
        start_day = w * 7
        end_day = min(start_day + 7, num_days)
        prob += pulp.lpSum(X[i][j][t] + X[j][i][t] for j in range(num_teams) for t in range(start_day, end_day)) >= 2 - S3[i][w]

# Solve
# prob.solve(GUROBI(msg = True))
prob.solve(pulp.PULP_CBC_CMD(msg=True))

# Output
print(f"\nStatus: {pulp.LpStatus[prob.status]}")
print(f"Objective value: {prob.objective.value()}\n")
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/z6/55zl8z_1365b2p_8lkhq6tzr0000gn/T/ea2b7150c2f343dfb98ae556cd396e3b-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/z6/55zl8z_1365b2p_8lkhq6tzr0000gn/T/ea2b7150c2f343dfb98ae556cd396e3b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 2694 COLUMNS
# At line 305288 RHS
# At line 307978 BOUNDS
# At line 322315 ENDATA
# Problem MODEL has 2689 rows, 15104 columns and 259265 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 704420 - 0.88 seconds
# Cgl0002I 448 variables fixed
# Cgl0003I 0 fixed, 0 tightened bounds, 42 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 41 strengthened rows, 0 substitutions
# ...

# %%
X = [[[int(pulp.value(X[i][j][t])) for t in range(num_days)] for j in range(num_teams)] for i in range(num_teams)]

X_array = np.array(X)

# --- Max 2 games in 3 days ---
violations_3days = 0
for i in range(num_teams):
    for t in range(num_days - 2):
        games_played = np.sum(X_array[i, :, t:t+3]) + np.sum(X_array[:, i, t:t+3])
        if games_played > 2:
            violations_3days += 1
            print(f"3-day violation: Team {i} plays {games_played} games from day {t} to {t+2}")
print(f"Total violations (max 2 games in 3 days): {violations_3days}\n")

# --- Max 3 games in 5 days ---
violations_5days = 0
for i in range(num_teams):
    for t in range(num_days - 4):
        games_played = np.sum(X_array[i, :, t:t+5]) + np.sum(X_array[:, i, t:t+5])
        if games_played > 3:
            violations_5days += 1
            print(f"5-day violation: Team {i} plays {games_played} games from day {t} to {t+4}")
print(f"Total violations (max 3 games in 5 days): {violations_5days}\n")

# --- Min 2 games per week (Sunday-Saturday) ---
violations_week = 0
start_day_index = 2  # Friday = day 0, Sunday = 2
first_sunday = (7 - start_day_index) % 7

for i in range(num_teams):
    for w in range(num_weeks):
        start_day = first_sunday + w * 7
        end_day = min(start_day + 7, num_days)
        games_played = np.sum(X_array[i, :, start_day:end_day]) + np.sum(X_array[:, i, start_day:end_day])
        if games_played < 2:
            violations_week += 1
            print(f"Week violation: Team {i} plays {games_played} games in week {w} (days {start_day}-{end_day - 1})")
print(f"Total violations (min 2 games per week): {violations_week}")
# Out:
# Total violations (max 2 games in 3 days): 0
#
# Total violations (max 3 games in 5 days): 0
#
# Week violation: Team 5 plays 1 games in week 1 (days 12-13)
# Week violation: Team 6 plays 1 games in week 1 (days 12-13)
# Week violation: Team 11 plays 1 games in week 1 (days 12-13)
# Week violation: Team 20 plays 1 games in week 1 (days 12-13)
# Week violation: Team 24 plays 1 games in week 1 (days 12-13)
# Week violation: Team 25 plays 1 games in week 1 (days 12-13)
# Week violation: Team 26 plays 1 games in week 1 (days 12-13)
# Week violation: Team 27 plays 1 games in week 1 (days 12-13)
# Total violations (min 2 games per week): 8

# %%
def lock_special_games(special_full, G_remaining, H_full, X_schedule):
    """
    Locks special games into the schedule by:
    - Setting X_schedule[(i, j, t)] = 1
    - Decreasing G_remaining[i, j]
    - Setting H_full[j, t] = 0
    """
    for i, j, t in special_full:
        # Mark the game as scheduled
        # X_schedule[(i, j, t)] = 1
        
        # Decrease the number of games remaining between i and j
        G_remaining[i, j] -= 1
        G_remaining[i, j] = max(G_remaining[i, j], 0)  # avoid negatives just in case

        # Update the home game count: j is the home team
        H_full[j, t] = 0
        return G_remaining, H_full

def compute_team_batch_allocation(X_schedule_current, num_teams, num_batches, batch_size, special):
    # Initialize a list to store the number of games for each team per batch
    games_per_batch_per_team = np.zeros((num_teams, num_batches), dtype=int)
    
    # Convert the special games into a set of (i, j, t) tuples for fast lookup
    special_set = set(tuple(game) for game in special)

    # Loop through all days and assign games to batches
    for t in range(num_days):
        # Determine which batch the current day falls into
        batch_idx = t // batch_size
        
        # Loop over all team pairs (i, j)
        for i in range(num_teams):
            for j in range(num_teams):
                if i != j:  # Only check for valid team pair (avoid i == j, no game against itself)
                    # Check if there's a game between team i and team j on day t
                    if (X_schedule_current[i][j][t] == 1 or X_schedule_current[j][i][t] == 1):
                        # Check if the game is in the special list (to exclude from count)
                        if (i, j, t) not in special_set and (j, i, t) not in special_set:
                            # If there's a game, increment the count of games for team i in the current batch
                            games_per_batch_per_team[i][batch_idx] += 1
    
    # games_per_batch_per_team now contains the number of games each team plays in each batch, excluding special games
    return games_per_batch_per_team

# %%
def optimize_schedule_in_batches(
    num_teams, num_days, A_full, G_full, H_full, special_full, batch_size=15,
    M1=1000, M2=500, M3=500
):

    num_batches = ceil(num_days / batch_size)
    # avg_games_per_batch = 82 // num_batches
    
    X_schedule = {}  # Final schedule as dict {(i, j, t): 0 or 1}
    G_remaining = G_full.copy()
    H_working = H_full.copy()  # optional: if you want to preserve original

    G_remaining, H_working = lock_special_games(special_full, G_remaining, H_working, X_schedule)

    # team_batch_game_alloc = compute_team_batch_allocation(H_full, num_teams, num_days, batch_size)
    team_batch_game_alloc = compute_team_batch_allocation(X_schedule_current, num_teams, num_batches, batch_size, special)

    # for b in range(num_batches):
    # Create a list of batches to prioritize: e.g., first, last, and then other batches
    #priority_batches = [0, num_batches - 1]  # First and last batch
    #other_batches = [b for b in range(1, num_batches - 1)]  # All batches except first and last
    #batches_to_optimize = priority_batches + other_batches  # Combine prioritized batches with the rest

    #for b in batches_to_optimize:
    for b in range(num_batches - 1, -1, -1):
        print(f"--- Optimizing batch {b+1}/{num_batches} ---")
        start_day = b * batch_size
        end_day = min(start_day + batch_size, num_days)
        local_days = end_day - start_day
        local_weeks = ceil(local_days / 7)

        # Problem
        prob = pulp.LpProblem(f'scheduling_batch_{b}', pulp.LpMaximize)

        # Vars
        X = pulp.LpVariable.dicts('X', (range(num_teams), range(num_teams), range(local_days)), cat='Binary')
        S1 = pulp.LpVariable.dicts('S1', (range(num_teams), range(max(0, local_days - 2))), lowBound=0)
        S2 = pulp.LpVariable.dicts('S2', (range(num_teams), range(max(0, local_days - 4))), lowBound=0)
        S3 = pulp.LpVariable.dicts('S3', (range(num_teams), range(local_weeks)), lowBound=0)

        # Objective
        prob += (
            pulp.lpSum(X[i][j][t] * A_full[i][j][start_day + t] for i in range(num_teams) for j in range(num_teams) for t in range(local_days))
            - M1 * pulp.lpSum(S1[i][t] for i in range(num_teams) for t in range(max(0, local_days - 2)))
            - M2 * pulp.lpSum(S2[i][t] for i in range(num_teams) for t in range(max(0, local_days - 4)))
            - M3 * pulp.lpSum(S3[i][w] for i in range(num_teams) for w in range(local_weeks))
            # + pulp.lpSum(
            #     # must schedule Utah HC (27) games as well throughout season (otherwise these get clogged in last batch)
            #     utah_pred_att * X[i][j][t]
            #     for i in [27] for j in range(num_teams) if i != j
            #     for t in range(local_days)
            # )
        )

        # A_days = num_days  # total number of days

        # Home game constraint
        for j in range(num_teams):
            for t in range(local_days):
                prob += pulp.lpSum(X[i][j][t] for i in range(num_teams)) == H_working[j, start_day + t]

        # Game requirement constraint
        for i in range(num_teams):
            for j in range(num_teams):
                prob += pulp.lpSum(X[i][j][t] for t in range(local_days)) <= G_remaining[i, j]

        # Fairness
        for i in range(num_teams):
            for t in range(local_days):
                prob += pulp.lpSum(X[i][j][t] + X[j][i][t] for j in range(num_teams)) <= 1
        for i in range(num_teams):
            for t in range(max(0, local_days - 2)):
                prob += pulp.lpSum(X[i][j][tp] + X[j][i][tp] for j in range(num_teams) for tp in range(t, t + 3)) <= 2 + S1[i][t]
            for t in range(max(0, local_days - 4)):
                prob += pulp.lpSum(X[i][j][tp] + X[j][i][tp] for j in range(num_teams) for tp in range(t, t + 5)) <= 3 + S2[i][t]
        for i in range(num_teams):
            for w in range(local_weeks):
                w_start = w * 7
                w_end = min((w + 1) * 7, local_days)
                prob += pulp.lpSum(X[i][j][t] + X[j][i][t] for j in range(num_teams) for t in range(w_start, w_end)) >= 2 - S3[i][w]

        # Ensure each team plays approximately avg_games_per_batch games in each batch
        # for i in range(num_teams):
        #     prob += pulp.lpSum(X[i][j][t] + X[j][i][t] for j in range(num_teams) for t in range(local_days)) >= (avg_games_per_batch - 3)
        #     prob += pulp.lpSum(X[i][j][t] + X[j][i][t] for j in range(num_teams) for t in range(local_days)) <= (avg_games_per_batch + 20)

        # games per batch constraint (not for last 2 batches)
        # if b in range(num_batches - 2):
        #     for i in range(num_teams):
        #         team_games = pulp.lpSum(X[i][j][t] + X[j][i][t] for j in range(num_teams) for t in range(local_days))
        #         prob += team_games <= team_batch_game_alloc[i][b] + 1
        #         prob += team_games >= team_batch_game_alloc[i][b] - 1

        for i in range(num_teams):
            team_games = pulp.lpSum(X[i][j][t] + X[j][i][t] for j in range(num_teams) for t in range(local_days))
            prob += team_games == team_batch_game_alloc[i][b]
            
        # Solve
        prob.solve(pulp.PULP_CBC_CMD(msg=False))
        
        print(f"Batch {b+1} status:", pulp.LpStatus[prob.status], "| Objective:", pulp.value(prob.objective))

        if pulp.LpStatus[prob.status] == 'Infeasible':
            print(f"G_remaining before Batch {b+1}:")
            for i in range(num_teams):
                for j in range(num_teams):
                    if G_remaining[i, j] > 0:
                        print(f"{i} vs {j}: {G_remaining[i, j]}")
            
            print(f"H_working for Batch {b+1}:")
            for j in range(num_teams):
                home_days = [t for t in range(start_day, end_day) if H_working[j, t] == 1]
                print(f"Team {j} has {len(home_days)} home slots: {home_days}")

        
        # add in special games last
        for i, j, t in special_full:
            # Mark the game as scheduled
            X_schedule[(i, j, t)] = 1

        # Store result and update game requirements
        for i in range(num_teams):
            for j in range(num_teams):
                for t_local in range(local_days):
                    t_global = start_day + t_local
                    val = int(pulp.value(X[i][j][t_local]))
                    if val == 1:
                        X_schedule[(i, j, t_global)] = 1
                        G_remaining[i, j] -= 1
                    else:
                        X_schedule[(i, j, t_global)] = 0

    return X_schedule

# %%
X_schedule = optimize_schedule_in_batches(
    num_teams=32,
    num_days=len(unique_days),
    A_full=A,               # shape (teams, teams, days)
    G_full=G.copy(),        # shape (teams, teams)
    H_full=H.copy(),        # dict {(j, t): value}
    special_full=special,   # list of (i, j, t)
    batch_size=20
)
# Out:
# --- Optimizing batch 9/9 ---
# Batch 9 status: Optimal | Objective: 2279192.0
# --- Optimizing batch 8/9 ---
# Batch 8 status: Optimal | Objective: 2508156.0
# --- Optimizing batch 7/9 ---
# Batch 7 status: Infeasible | Objective: 2552234.1636842
# G_remaining before Batch 7:
# 0 vs 1: 1
# 0 vs 2: 1
# 0 vs 3: 2
# 0 vs 4: 1
# 0 vs 5: 1
# 0 vs 6: 1
# 0 vs 9: 1
# 0 vs 10: 2
# 0 vs 11: 1
# 0 vs 12: 2
# 0 vs 13: 1
# 0 vs 14: 1
# 0 vs 16: 1
# 0 vs 18: 1
# 0 vs 19: 1
# 0 vs 20: 1
# 0 vs 21: 1
# 0 vs 22: 1
# 0 vs 23: 2
# 0 vs 24: 2
# 0 vs 25: 1
# 0 vs 26: 1
# 0 vs 28: 1
# 0 vs 29: 2
# 0 vs 30: 1
# 0 vs 31: 1
# 1 vs 0: 1
# 1 vs 2: 2
# 1 vs 3: 1
# 1 vs 4: 2
# 1 vs 6: 1
# 1 vs 7: 1
# 1 vs 8: 1
# 1 vs 9: 2
# 1 vs 10: 1
# 1 vs 12: 1
# 1 vs 13: 1
# 1 vs 14: 1
# 1 vs 15: 1
# 1 vs 18: 2
# 1 vs 19: 1
# 1 vs 20: 1
# 1 vs 21: 2
# 1 vs 22: 1
# 1 vs 23: 1
# 1 vs 24: 1
# 1 vs 25: 1
# 1 vs 26: 2
# 1 vs 27: 1
# 1 vs 28: 1
# 1 vs 29: 1
# 2 vs 0: 1
# 2 vs 1: 2
# 2 vs 4: 1
# 2 vs 5: 1
# 2 vs 9: 2
# 2 vs 10: 1
# ...

# %%
X_schedule

# %%
def compute_team_batch_allocation(X_schedule_current, num_teams, num_batches, batch_size):
    # Initialize a list to store the number of games for each team per batch
    games_per_batch_per_team = np.zeros((num_teams, num_batches), dtype=int)
    
    # Loop through all days and assign games to batches
    for t in range(num_days):
        # Determine which batch the current day falls into
        batch_idx = t // batch_size
        
        # Loop over all team pairs (i, j)
        for i in range(num_teams):
            for j in range(num_teams):
                if i != j:  # Only check for valid team pair (avoid i == j, no game against itself)
                    # Check if there's a game between team i and team j on day t
                    if X_schedule_current[i][j][t] == 1 or X_schedule_current[j][i][t] == 1:
                        # If there's a game, increment the count of games for team i in the current batch
                        games_per_batch_per_team[i][batch_idx] += 1
    
    # games_per_batch_per_team now contains the number of games each team plays in each batch
    return games_per_batch_per_team

# %%
def compute_team_batch_allocation(X_schedule_current, num_teams, num_batches, batch_size, special):
    # Initialize a list to store the number of games for each team per batch
    games_per_batch_per_team = np.zeros((num_teams, num_batches), dtype=int)
    
    # Convert the special games into a set of (i, j, t) tuples for fast lookup
    special_set = set(tuple(game) for game in special)

    # Loop through all days and assign games to batches
    for t in range(num_days):
        # Determine which batch the current day falls into
        batch_idx = t // batch_size
        
        # Loop over all team pairs (i, j)
        for i in range(num_teams):
            for j in range(num_teams):
                if i != j:  # Only check for valid team pair (avoid i == j, no game against itself)
                    # Check if there's a game between team i and team j on day t
                    if (X_schedule_current[i][j][t] == 1 or X_schedule_current[j][i][t] == 1):
                        # Check if the game is in the special list (to exclude from count)
                        if (i, j, t) not in special_set and (j, i, t) not in special_set:
                            # If there's a game, increment the count of games for team i in the current batch
                            games_per_batch_per_team[i][batch_idx] += 1
    
    # games_per_batch_per_team now contains the number of games each team plays in each batch, excluding special games
    return games_per_batch_per_team

# %%
compute_team_batch_allocation(X_schedule_current, num_teams, num_batches, batch_size, special)
# Out:
# array([[ 6,  9,  9, 10, 11,  8, 10, 10,  9],
#        [ 8, 10, 10, 10,  8, 10,  9,  9,  8],
#        [ 6,  9,  9, 10,  9,  8, 10, 10,  9],
#        [ 7, 10, 10,  8,  9, 10,  9,  9, 10],
#        [ 6,  9, 11, 10, 10,  9,  9,  9,  9],
#        [ 8,  9,  9, 10,  8,  8, 12,  9,  8],
#        [ 8,  9, 10, 10,  9, 10,  9,  9,  8],
#        [ 6,  9, 10, 12,  8, 10,  7,  9, 10],
#        [ 8,  5, 10,  9, 10,  9, 11,  9,  9],
#        [ 7,  8, 11,  9,  9, 10,  9,  9,  9],
#        [ 8,  9,  9,  9, 10,  9, 10,  9,  9],
#        [ 9,  6, 10, 10,  9, 10,  8,  9,  9],
#        [ 8, 10,  8,  9,  7,  9, 11, 11,  9],
#        [ 7,  9,  9, 11,  9, 10,  9, 10,  8],
#        [ 7, 10,  9,  9,  9, 10,  9, 10,  9],
#        [ 7, 10, 10,  9,  8,  8, 11, 10,  9],
#        [ 9,  9,  8, 11,  8,  9,  9, 10,  7],
#        [ 7, 10, 10,  9,  8,  9, 10, 10,  9],
#        [ 7,  8,  9, 11,  9,  9, 11, 10,  8],
#        [ 7,  9,  9, 10,  9, 11,  8, 10,  9],
#        [ 7, 10,  9, 10, 10, 10,  9, 10,  7],
# ...
